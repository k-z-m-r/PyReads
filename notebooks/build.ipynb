# %% [markdown]
# ### TODO:
# 1. Function-ify everything.
# 3. Add "Library"
# 4. Code optimizations
# 5. Docstrings ofc

# %%
import sys

sys.path.append('../')

from pyreads import get_library

# %%
user_id = 177424567

# %%
library = get_library(user_id)

# %%
library
# Out:
# Library(owner=177424567, books=[Book(title='Brave New World', series=None, seriesNumber=None, authorName='Huxley, Aldous', dateRead=datetime.datetime(2025, 7, 6, 0, 0), userRating=4, review=None), Book(title='The Hellbound Heart', series=None, seriesNumber=None, authorName='Barker, Clive', dateRead=datetime.datetime(2025, 6, 21, 0, 0), userRating=4, review=None), Book(title='One Day, Everyone Will Have Always Been Against This', series=None, seriesNumber=None, authorName='El Akkad, Omar', dateRead=datetime.datetime(2025, 6, 21, 0, 0), userRating=5, review=None), Book(title='The Haunting of Hill House', series=None, seriesNumber=None, authorName='Jackson, Shirley', dateRead=datetime.datetime(2025, 3, 12, 0, 0), userRating=4, review=None), Book(title='Fry Bread: A Native American Family Story', series=None, seriesNumber=None, authorName='Maillard, Kevin Noble', dateRead=datetime.datetime(2025, 3, 7, 0, 0), userRating=5, review=None), Book(title='The Last Cuentista', series=None, series
# ...

# %%
library.dataframe
# Out:
#                                                  title    series  \
# 0                                      Brave New World      None
# 1                                  The Hellbound Heart      None
# 2    One Day, Everyone Will Have Always Been Agains...      None
# 3                           The Haunting of Hill House      None
# 4            Fry Bread: A Native American Family Story      None
# ..                                                 ...       ...
# 142             Claymore, Vol. 4: Marked for the Death  Claymore
# 143        Claymore, Vol. 3: Teresa of the Faint Smile  Claymore
# 144             Claymore, Vol. 2: Darkness in Paradise  Claymore
# 145               Claymore, Vol. 1: Silver-eyed Slayer  Claymore
# 146                             Dracula, Motherf**ker!      None
#
#      seriesNumber             authorName   dateRead  userRating review
# 0             NaN         Huxley, Aldous 2025-07-06           4   None
# ...
